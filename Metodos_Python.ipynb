# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
# %pip install openpyxl

# %%
#Carga desde un archivo .xlsx sin indice
Inmuebles= pd.read_excel('Inmuebles.xlsx', skiprows=1)
Inmuebles
# Out:
#       Referencia Fecha_Alta        Tipo Operación  Provincia  Superficie  \
# 0              1 2004-01-01     Parking  Alquiler     Lleida       291.0
# 1              2 2004-01-01       Local     Venta     Girona       185.0
# 2              3 2004-01-01     Oficina  Alquiler     Girona        82.0
# 3              4 2004-01-02     Parking  Alquiler     Girona       285.0
# 4              5 2004-01-02       Suelo     Venta  Tarragona       152.0
# ...          ...        ...         ...       ...        ...         ...
# 3332        3333 2007-04-29  Industrial  Alquiler     Lleida       221.0
# 3333        3334 2007-04-29        Piso  Alquiler     Girona        55.0
# 3334        3335 2007-04-30       Suelo     Venta  Tarragona        78.0
# 3335        3336 2007-04-30        Piso  Alquiler  Barcelona        88.0
# 3336        3337 2007-04-30     Parking     Venta     Lleida       254.0
#
#       Precio Venta Fecha Venta Vendedor
# 0        2133903.0  2004-06-19   Carmen
# ...

# %%
#Carga desde un archivo .csv sin indice y con decodificación. Ejemplos: 'ascii', 'UTF-8'
Test_DATA = pd.read_csv("Test Data.csv", encoding= 'latin')
Test_DATA

# %%
# Limitar el número máximo de columnas
pd.options.display.max_columns = 10

# %%
# Ajustar maximo de columnas
pd.options.display.max_columns = None

# %%
# Limitar numero máximo de filas
pd.options.display.max_rows = 20

# %%
# Ajustar maximo de filas
pd.options.display.max_rows = None

# %%
#Conversión de tipo de dato de columna de tipo Object a Float
Inmuebles['Fecha_Alta']= Inmuebles['Fecha_Alta'].astype(float)

# %%
#Eliminar un signo de una columna 
Inmuebles['Columna']=Inmuebles['Columna'].str.replace('o', '0')

# %%
#Reemplazo de datos tipo string a datos tipo numérico
df.CVE_CLPV = df.CVE_CLPV.replace({'%':''}, regex=False)

# %%
#Analizar categorias de una columna
df6 = data2.groupby(['Tipo'])['Tipo'].count()
df6

# %%
#Carga de un archivo .xlsx desde un libro con varias páginas
df= pd.read_excel('Gastos y costos 20-23.xlsx', sheet_name = '2023', skiprows=3)
df
# Out:
#          Fecha       Folio                                  UUID  \
# 0   2023-01-01          31  49536321-60A4-523E-A32F-E8BDF5C2276E
# 1   2023-01-01          38  20FBB63B-D550-512F-9668-EEC6F983CEB7
# 2   2023-01-01      341932  DB8C4388-D4E0-4F0C-A09C-77C773257F44
# 3   2023-01-01      341933  A81A63F5-D5EC-4601-803E-375AF9CC5021
# 4   2023-01-01      342205  DCC10492-DE51-4C87-8430-5676FBF81931
# ..         ...         ...                                   ...
# 392 2023-02-01      882974  3E97C399-6747-4BCA-8436-ED4B0933DF33
# 393 2023-02-01      053560  B7132758-F800-4797-B1D6-CC61AFFEE444
# 394 2023-02-01  1092957089  D1E2DC1E-9FFB-46C6-82E4-B350B83CB6F7
# 395 2023-02-01     1453820  6249FE27-6FA6-4EFB-910E-3CD67A0E29A1
# 396 2023-02-01          18  439A9230-277E-5563-818C-7630B0E8D706
#
#               RFC                                          Proveedor  \
# 0    AAE6411055P8                          AESA ARTICULOS ELECTRICOS
# ...

# %%
#Método para ordenamiento de categorias en un data frame

cats = ['January','February','March','April','May','June',
        'July','August','September','October','November','December']
df['month'] = pd.CategoricalIndex(df['month'], ordered=True, categories=cats)
#alternative
#df['month'] = pd.Categorical(df['month'], ordered=True, categories=cats)
df = df.sort_values('month')

# %%
#Categorización de variables
#Declaramos 2 intervalos (menores de 100) y (mayores de 100)
intervalos=[-math.inf, 100, math.inf ]
categorias= ["reducida", "extensa"]
Inmuebles['TipoDeSuperficie']=pd.cut(x= Inmuebles['Superficie'], bins=intervalos, labels= categorias )
Inmuebles
# Out:
#       Referencia Fecha_Alta        Tipo Operación  Provincia  Superficie  \
# 0              1 2004-01-01     Parking  Alquiler     Lleida       291.0
# 1              2 2004-01-01       Local     Venta     Girona       185.0
# 2              3 2004-01-01     Oficina  Alquiler     Girona        82.0
# 3              4 2004-01-02     Parking  Alquiler     Girona       285.0
# 4              5 2004-01-02       Suelo     Venta  Tarragona       152.0
# ...          ...        ...         ...       ...        ...         ...
# 3332        3333 2007-04-29  Industrial  Alquiler     Lleida       221.0
# 3333        3334 2007-04-29        Piso  Alquiler     Girona        55.0
# 3334        3335 2007-04-30       Suelo     Venta  Tarragona        78.0
# 3335        3336 2007-04-30        Piso  Alquiler  Barcelona        88.0
# 3336        3337 2007-04-30     Parking     Venta     Lleida       254.0
#
#       Precio Venta Fecha Venta Vendedor TipoDeSuperficie
# ...

# %%
#Agregar un signo de una columna 
tablero['percentage']=tablero['percentage'].apply("{:%}".format)

# %%
#Agregar un signo de una columna 
tablero['percentage']=tablero['percentage']+ '%'

# %%
#Filas incrementales en un fator
filas= df.iloc[0::200,:] #Filas con incrementos de 200 a partir de la fila 0

# %%
#Columnas incrementales en un fator
columnas= df.iloc[:, 1::2] #Columnas con incrementos de 2 a partir de la columna 1

# %%
#Todas las filas hasta un límite
filas = df.iloc[:200, :] #Todas las Filas hasta la 200

# %%
#Todas las columnas hasta un límite
columnas = df.iloc[:, :5] #Todas las Columnas hasta la 5

# %%
#Rangos en filas 
filas = df.iloc[1:200:2,:]# Filas de 1 a 200 con incrementos de 2

# %%
#Rangos en columnas
columnas = df.iloc[:,0:10:3]# Columnas de 0 a 10 con incrementos de 3

# %%
#Guardar varios dataframe en un solo archivo Excel con una sola hoja
df_total = pd.concat([df1, df2, df3], ignore_index=True)

df_total.to_excel('resultado_concatenado.xlsx', index=False)

# %%
# Guardar varios dataframe en un solo archivo Excel con varias hojas (Libro)
df1
df2
df3
with pd.ExcelWriter('mi_archivo.xlsx') as writer:
    df1.to_excel(writer, sheet_name='Personas', index=False)
    df2.to_excel(writer, sheet_name='Productos', index=False)
    df3.to_excel(writer, sheet_name='Ciudades', index=False)

# %%
# Mostrar los índices de esas filas
indices_con_nulos = filas_con_nulos.index.tolist()

print("Índices con nulos:", indices_con_nulos)
